# %%
# !pip install -r /Users/riymchaouiaziz/Desktop/FAIDML-project/FAIML-RL-26/requirements.txt -q

# %% [markdown]
# ---

# %% [markdown]
# ### Test a random policy on the Gym Hopper environment
#
#
#
#
#
# Play around with this code to get familiar with the
# Hopper environment.
#
# For example, what happens if you don't reset the environment
# even after the episode is over?
# When exactly is the episode over?
# What is an action here?

# %%
import gymnasium as gym

# %%
env = gym.make('Hopper-v4', render_mode='rgb_array')

print('State space:', env.unwrapped.observation_space)  # state-space
print('Action space:', env.action_space)  # action-space
# Out:
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)

# %%
n_episodes = 5

for episode in range(n_episodes):
  done = False
  observation = env.reset()	 # Reset environment to initial state

  while not done:  # Until the episode is over

    action = env.action_space.sample()	# Sample random action

    observation, reward, terminated, truncated, _ = env.step(action)	# Step the simulator to the next
    done = terminated or truncated

# %% [markdown]
# # Rendering
# Interactive simulation are difficult to run but you can use rgb array as rendering mode to obtain an image. You can create videos later if you render at each timestamp.

# %%
# !pip install pyvirtualdisplay

# %%
from IPython.display import HTML
from IPython import display as ipythondisplay
from pyvirtualdisplay import Display

# Start virtual display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 6
#       3 from pyvirtualdisplay import Display
#       5 # Start virtual display
# ----> 6 display = Display(visible=0, size=(1400, 900))
#       7 display.start()
#
# File ~/Desktop/FAIDML-project/FAIML-RL-26/FAIMDL/lib/python3.10/site-packages/pyvirtualdisplay/display.py:54, in Display.__init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, retries, extra_args, manage_global_env, **kwargs)
#      51 if not cls:
#      52     raise ValueError("unknown backend: %s" % self._backend)
# ---> 54 self._obj = cls(
#      55     size=size,
#      56     color_depth=color_depth,
#      57     bgcolor=bgcolor,
#      58     retries=retries,
#      59     use_xauth=use_xauth,
#      60     # check_startup=check_startup,
#      61     extra_args=extra_args,
# ...

# %%
res = env.render()

# %%
res
# Out:
# array([[[ 67,  84, 101],
#         [ 67,  84, 101],
#         [ 67,  84, 101],
#         ...,
#         [ 67,  84, 101],
#         [ 67,  84, 101],
#         [ 67,  84, 101]],
#
#        [[ 67,  84, 101],
#         [ 67,  84, 101],
#         [ 67,  84, 101],
#         ...,
#         [ 67,  84, 101],
#         [ 67,  84, 101],
#         [ 67,  84, 101]],
#
#        [[ 67,  84, 101],
#         [ 67,  84, 101],
#         [ 67,  84, 101],
#         ...,
#         [ 67,  84, 101],
#         [ 67,  84, 101],
#         [ 67,  84, 101]],
#
#        ...,
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [179, 202, 179],
#         [179, 202, 179],
#         [179, 202, 179]],
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
#         ...,
#         [179, 202, 179],
#         [179, 202, 179],
#         [179, 202, 179]],
#
#        [[  0,   0,   0],
#         [  0,   0,   0],
#         [  0,   0,   0],
# ...

# %%
import gymnasium as gym

# 1. Change render_mode to 'human'
env = gym.make('Hopper-v4', render_mode='human')

print('State space:', env.observation_space)
print('Action space:', env.action_space)

n_episodes = 5

for episode in range(n_episodes):
    done = False
    observation, info = env.reset()  # Reset environment to initial state

    while not done:
        # 2. Tell the environment to draw the current frame
        env.render()
        
        action = env.action_space.sample()  # Sample random action
        
        # Step the simulator to the next state
        observation, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

# 3. Close the window when finished
env.close()
# Out:
# /Users/riymchaouiaziz/Desktop/FAIDML-project/FAIML-RL-26/FAIMDL/lib/python3.10/site-packages/gymnasium/envs/registration.py:512: DeprecationWarning: WARN: The environment Hopper-v4 is out of date. You should consider upgrading to version `v5`.
#   logger.deprecation(
# State space: Box(-inf, inf, (11,), float64)
# Action space: Box(-1.0, 1.0, (3,), float32)
